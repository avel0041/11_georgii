# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from fnmatch import *
for i in range(2024, 10**10, 2024):
    if fnmatch(str(i), '1?2157*4'):
        print(i, i//2024)

# %% [markdown]
# ### Найти все делители числа

# %%
def y_del(a):
    w=[]
    i = 1
    while i*i<=a:
        if a%i==0:
            w.append(i)
            w.append(a//i)
        i += 1
    return set(w)
q=100
print(sorted(y_del(q)))
# Out:
# [1, 2, 4, 5, 10, 20, 25, 50, 100]

# %% [markdown]
# ### Найти все простые делители числа

# %%
def y_del(a):
    w=[]
    i = 2
    while i*i<=a:
        if a%i==0:
            w.append(i)
            a = a//i
        else:
            i += 1
    if a > 1:
        w.append(a)
    return w
q=112508413
print(sorted(y_del(q)))
# Out:
# [10601, 10613]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
i = 600_000
c=0
q=[]
a=[]
while c < 5:
    for w in range(17,i//2, 10):
        if i%w==0:
            a.append(i)
            q.append(w)
            c=c+1
            break    
    i=i+1

print(a,q)
# Out:
# [600001, 600002, 600003, 600005, 600012] [437, 47, 1227, 217, 16667]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for i in range(2000_000, 3_000_001):
    c=0
    w = 1000
    while w*w<=i:
        if i%w==0:
            if i//w-w<=115:
                c=c+1
                if c>2:
                    break
        w += 1
    if c>=3:
        print(i)
# Out:
# 2053440
# 2098080
# 2328480
# 2638944

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
q=[]
for i in range(112_500_000, 112_550_001):
    s=0
    c=0
    j = 0
    for w in range(2, round(i**0.5)+1):
        if i%w==0:
            c=c+i//w
            s=s+1
            j += 1
        if s==2:
            break
    if j == 1 and c!= i//c:
        c += i//c
    if c % 10000 == 1214:
        q.append(i)

print(q)
# Out:
# [112508413, 112520369, 112523549, 112534952]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
2**1 + 3**5+ 5**4
(2+1)*(5+1)*(4+1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def f(n):
    q=[]
    for i in range(1, int(n**0.5)+1):
        if n%i==0:
            q.append(i)
            q.append(n//i)
    q=set(q)
    q=sorted(q)
    return(sum(q))

c=0
q=[]
a=[]
for i in range(500_000, 600_000000000000000):
    if str(f(i))[-1]=='6':
        c+=1
        q.append(i)
        a.append(f(i))
        if c==5:
            print(q)
            print(a)
            break
