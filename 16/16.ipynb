# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def f(n):
    if n==1 or n==2:
        return 1
    else:
        return f(n-2)* (n-1)


print(f(8))
# Out:
# 105

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# f(12345) = f(1234) = f(123) + 4 = f(12) + 4 = f(1) + 4 + 2 = f(0) + 4 + 2 = 2 + 4 = 6

print(6**9)
# Out:
# 10077696
