# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def v1(a):
    return ((a-2)<=87) or (a//2<=87)
def p1(a):
    return v1(a-2) and v1(a//2) and not(v1(a))
def v2(a):
    return p1(a-2) or p1(a//2) and not(v1(a))
def p2(a):
    return (v2(a-2) or v1(a-2)) and (v2(a//2) or v1(a//2)) and (v2(a-2) or v2(a//2)) and (not(v1(a)))


p=[]
for i in range(88, 1000):
    if p2(i)==1:
        p.append(i)

p=sorted(p)
print(p)
# Out:
# [180, 181, 356, 357]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def v1(a,b):
    return ((a+1+b>=67)) or ((a+b+b)>=67) or ((a+a+b)>=67) and  (a+b<67)
def p1(a,b):
    return (v1(a+1,b)) and (v1(a+b,b)) and v1(a,a+b) and (v1(a,b+1)) and not(v1(a,b))
def v2(a,b):
    return (p1(a+1,b)) or (p1(a+b,b)) or p1(a,a+b) or (p1(a,b+1)) and not(v1(a,b))
def p2(a,b):
    return (v1(a+1,b) or v2(a+1,b)) and (v1(a+b,b) or  v2(a+b,b)) and (v1(a,a+b) or v2(a,a+b)) and (v1(a,b+1) or  v2(a,b+1)) and (v2(a+1,b) or v2(a+b,b) or v2(a,a+b) or v2(a,b+1)) and not(v1(a,b))

def er1(a, b):
    return (v1(a+1,b)) or  (v1(a+b,b)) or v1(a,a+b) or (v1(a,b+1)) and not(v1(a,b))

i=9
f=[]
for t in range(1, 58):
    if p2(i, t)==1:
        f.append(t)

print(f)
# Out:
# [27]
