# %% [markdown]
# ![image.png](attachment:image.png)

# %%
9(2).txt

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
9(1).txt

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
9(3).txt

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
9(4).txt

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=open('9.txt')
s=a.readlines()
# учесть первую строчку
sum2=1000000
a1=[]
for i in range(0, len(s)): 
    q=s[i]
    q=q.split()
    l=[]
    for f in q:
        t=int(f)
        l.append(t)
    p = []
    n = []
    for el in l:
        if l.count(el) == 3:
            p.append(el)
        if l.count(el) == 1:
            n.append(el)
    if len(p)==3 and len(n)==4:
        if sum(n)/4>=p[0]:
            if max(l)%min(l)!=0:
                sum1=sum(l)
                if sum2>=sum1:
                    sum2=sum1
                    a1.append(i)

print(a1[-1] + 1)
