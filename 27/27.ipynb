# %% [markdown]
# ![image.png](attachment:image.png)

# %%
f = open('27-B_1.txt')
q=f.readlines()
q=q[1:]
d=10000000
sum=0
for i in q:
    i=i.split()
    i=list(map(int, i))
    sum+=max(i)
    if d>=abs(i[0]-i[1]) and ((max(i)-min(i))%5!=0):
        d=abs(i[0]-i[1])

print(sum)
# Out:
# 394491666

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
