# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=[]
for n in range(1, 1000):
    r=bin(n)[2:]
    k=r.count('1')%2
    r=str(r)+str(k)
    k=r.count('1')%2
    r=str(r)+str(k)
    R=int(r, 2)
    if R >77:
        a.append(n)
print(min(a))
# Out:
# 19

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=[]
for i in range(100, 1000):
    q=''
    s = str(i)
    k=int(s[0])+int(s[1])
    w=int(s[2])+int(s[1])
    if k>=w:
        q=str(w)+str(k)
    else:
        q=str(k)+str(w)
    if int(q) ==1115:
        a.append(i)
print(min(a))
# Out:
# 296
