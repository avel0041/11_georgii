# %% [markdown]
# ## Основные алгоритмы в ЕГЭ

# %%
# Перевод из одной СИ в другую
# из 10ной в любую
q=sorted(set('1234567890qwertyuiopasdfghjklzxcvbnm'))
print(len(q))
def a(x, n):
    s=''
    while x>0:
        s+=q[x%n]
        x=x//n
    return(s[::-1])
# из любой в 10ную
s=int(x, n)

# Поиск делителей числа

a=1234814862573
q=[]
for i in range(0, int(a**0.5)+1):
    if a%i==0:
        q.append(a//i)
        q.append(i)
q=sorted(set(q))
print(q)
# Поиск простых делителей числа
a=1234814862573
i = 2
w = []
while i*i<=a:
    if a%i == 0:
        w.append(i)
        a = a//i
    else:
        i += 1
if a > 1:
    w.append(a)
print(set(sorted(w)))
    

# Обработка текстового файла (преобразование в нормальный массив с int)
a=open('17_1.txt')
s=a.readlines()

w=[]
for i in s:
    w.append(int(i))
#или
s=list(map(int,s))
#или
for i in s:
    i=i.split()
    q=list(map(int,i))
    w.append(q)

# Поиск среднего арифметического
a=[1, 2, 3, 87, 54, 23]
t=sum(a)//len(a)

# Преобразование массива в строку
q=[]
for i in q:
    s+=i


a=234,232
w=int(a+0,5) # округление обычное

# Округление вверх
w = int(-(-a//1))
from math import *
w = ceil(a)

# Отбросить дробную часть
w=int(a)

# Проверка на принадлежность массиву или строки
a = '12345'
a = [1, 2, 3, 5, 5]
a=set(a)
c=0
if '3' in a:
    c=1

# Проверка 'все ли элементы удовлетворяют условию'
a = [1, 2, 3, 4, 5, 6, 7, -4, 6]
flag=1
for i in a:
    if i<0:
        flag=0
if flad==0:
    print('не выполнено')
# Out:
# 36
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 12>()
#      10     return(s[::-1])
#      11 # из любой в 10ную
# ---> 12 s=int(x, n)
#      14 # Поиск делителей числа
#      16 a=1234814862573
#
# NameError: name 'x' is not defined

# %%
a=1234814862573
q=[]
for i in range(1, int(a**0.5)+1):
    if a%i==0:
        q.append(a//i)
        q.append(i)
q=sorted(set(q))
print(q)

a=1234814862573
i = 2
w = []
while i*i<=a:
    if a%i == 0:
        w.append(i)
        a = a//i
    else:
        i += 1
if a > 1:
    w.append(a)
print(sorted(w))
# Out:
# [1, 3, 9, 27, 43, 81, 129, 387, 1161, 3483, 354526231, 1063578693, 3190736079, 9572208237, 15244627933, 28716624711, 45733883799, 137201651397, 411604954191, 1234814862573]
# [3, 3, 3, 3, 43, 354526231]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def f(a,b,s):
    if a>b or s[-2:] == '22':
        return 0
    elif a == b:
        return 1
    else:
        return f(a+1, b, s + '1')+f(a+2, b, s + '2')+f(a*2, b, s + '3')

print(f(2,22, ''))
# Out:
# 4953

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from itertools import *
q=[]
c=0
for r in range(1,11):
    a=list(permutations('0123456789', r=r))
    for t in a:
        # s = ''.join(t)
        s=''
        for i in t:
            s+=str(i)
            
        if t[0]!='0' and int(s)%5==0:
            c+=1

print(c+1)
# Out:
# 1863218

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from itertools import *
a=list(product('0123456789AB', repeat=5))

c=0
for i in a:
    if i[0]!='0' and i.count('7')==1 and (i.count('9')+i.count('A')+i.count('B'))<=3:
        c+=1
print(c)
# Out:
# 67476

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from itertools import *

a=list(product('1234', repeat=5))
c=0
for i in a:
    s=''
    for t in i:
        s+=t
    if i.count('2')<=2 and not('13' in s or '31' in s)==1:
        c+=1
print(c)
# Out:
# 536

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#a,b,c
#a,b,c>=0 or a,b,c=<0
#min*max>min(p)**2

a=open('17_1.txt')
s=a.readlines()
s=list(map(int,s))
p=[]

for t in s:
    if t<0 and len(str(t))==4 and str(t)[-2:]=='15':
        d=t**2
        p.append(d)
y=max(p)

a1=[]
c=0
for i in range(1,len(s)-1):
    w=[]
    if (s[i-1]>=0 and s[i]>=0 and s[i+1]>=0) or (s[i-1]<0 and s[i]<0 and s[i+1]<0):
        w.append(s[i-1])
        w.append(s[i])
        w.append(s[i+1])
        pr=min(w)*max(w)
        if min(w)*max(w)>y:
            c+=1
            a1.append(min(w)*max(w))

print(c, min(a1))
# Out:
# 3507 863808

# %%
print(len(str(-34)))
# Out:
# 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s = ['012345', '1', '123333333', '012']
q=[]
for i in s:
    while i[-1] in '13579BD':
        i=i[:-1]
        if len(i)==0:
            break
    if len(i)!=0:   
        while i[0]=='0':
            i=i[1:]
            if len(i)==0:
                break
    q.append(len(i))

print(max(q))
# Out:
# 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for i in range
