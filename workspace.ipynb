# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Делаем тоже самое, но с 12-ричной записью
# Результат работы больше, чем 777777
def n12(x):
    s=''
    a = '0123456789ABCDEF'
    while x>0:
        s+=a[x%12]
        x=x//12
    return s[::-1]


a=[]
for i in range(0,77777):
    c=n12(i)
    d=0
    for w in range(0, len(c)):
        d+=int(c[w], 12)
    c=c+str(d%2)

    d=0

    for w in range(0, len(c)):
        d+=int(c[w], 12)
    c=c+str(d%2)

    r=int(c,12)
    if r>777777:
        a.append(i)

print(min(a))
# Out:
# 5402

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from itertools import *
a=list(permutations('0123456789', r=4))
c=0
for i in a:
    if i[0]!='0' and len(set(i))==4:
        flag=1
        for p in range(0, len(i)-1):
            if  int(i[p])%2==int(i[p+1])%2:
                flag=0
        if flag==1:
            c+=1

print(c)
# Out:
# 720

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=open('9.txt')
s=a.readlines()
# учесть первую строчку
sum2=1000000
a1=[]
for i in range(0, len(s)): 
    q=s[i]
    q=q.split()
    l=[]
    for f in q:
        t=int(f)
        l.append(t)
    p = []
    n = []
    for el in l:
        if l.count(el) == 3:
            p.append(el)
        if l.count(el) == 1:
            n.append(el)
    if len(p)==3 and len(n)==4:
        if sum(n)/4>=p[0]:
            if max(l)%min(l)!=0:
                sum1=sum(l)
                if sum2>=sum1:
                    sum2=sum1
                    a1.append(i)

print(a1[-1] + 1)
# Out:
# 3806

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 01321313213123213210
# 010 -> 1030 -> 121100
# 020 -> 2010 -> 21030 -> 2121100
# 030 -> 21100
# x1 - количесвто 1
# x2 - количесвто 2
# x3 - количесвто 3

# 196 (количество 1 в конечной строке) = 3*x1 + 3*x2 + 2*x3
# 75 = x1 + 2*x2 + x3
# x1+x2+x3 -> min
a=[]
for x in range(100):
    for y in range(100):
        for z in range(100):
            if x+2*y+z==75 and 3*x+3*y+z*2==196:
                a.append(x+y+z)

print(min(a)+2)
# Out:
# 68

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for x in range(2300,0,-1):
    c=0
    a=7**350+7**150-x
    while a>0:
        if a%7==0:
            c+=1
        
        a=a//7
    if c==200:
        print(x)
        break
# Out:
# 2001

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Out:
# 19

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=open('17.txt')
s=a.readlines()

el=0
for u in s:
    if u[-3:] == '19\n' and el<int(u):
        el=int(u)

print(el)
rt=0
a2 = 0
for i in range(0, len(s)-2):
    c=0
    x = s[i]
    y = s[i+1]
    z = s[i+2]
    f1=0
    f2=0
    f3=0
    if len(x)==5:
        c+=1
    if len(y)==5:
        c+=1
    if len(z)==5:
        c+=1
    if c==2:
        f1=1
    if int(x)%3==0 or int(y)%3==0 or int(z)%3==0:
        f2=1
    a1=int(x)+int(y)+int(z)
    if a1>el:
        f3=1
    if f1+f2+f3==3:
        rt+=1
        if a1>a2:
            a2=a1
print(a2,rt)
# Out:
# 82619
# 115709 78

# %%
a=open('17.txt')
s=a.readlines()
print(s)
# Out:
# ['6633\n', '4838\n', '33100\n', '55\n', '86\n', '95340\n', '9008\n', '6786\n', '99\n', '81\n', '4889\n', '989\n', '49498\n', '8751\n', '66\n', '61758\n', '349\n', '48\n', '447\n', '83\n', '85\n', '981\n', '11366\n', '7895\n', '527\n', '16979\n', '41608\n', '82709\n', '915\n', '2784\n', '23905\n', '5240\n', '79\n', '22235\n', '76553\n', '40\n', '485\n', '995\n', '2332\n', '11780\n', '263\n', '811\n', '35751\n', '82826\n', '93192\n', '67583\n', '67\n', '4680\n', '3858\n', '7742\n', '132\n', '214\n', '43\n', '201\n', '525\n', '56651\n', '73974\n', '3029\n', '79\n', '3184\n', '411\n', '87\n', '952\n', '2512\n', '883\n', '3312\n', '854\n', '203\n', '44125\n', '45\n', '27884\n', '902\n', '257\n', '114\n', '48\n', '24\n', '77\n', '56475\n', '11711\n', '9683\n', '9812\n', '69997\n', '35899\n', '634\n', '59237\n', '8372\n', '7700\n', '88\n', '745\n', '83\n', '70\n', '737\n', '5755\n', '3121\n', '2073\n', '44\n', '62159\n', '95\n', '411\n', '44\n', '3084\n', '194\n', '728\n', '5181\n', '61817\
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=open('24.txt')
s=a.readline()
q=[]
p=0
s1='LDRLDRTYLTLDRLDRLR'
S1='**TYLT**LR'
s=s.replace('LDR', '*')
s=s.replace('LD', '!')

p=0
q=[]
for i in range(0, len(s)-1):
    if s[i]=='*':
        p+=3
        q.append(p)
        if s[i+1]=='!':
            p+=2
            q.append(p)
            p=0
        if s[i+1]=='L':
            p+=1
            q.append(p)
            p=0
        
    else:
        p=0
 
print(max(q))
print(len('LDRLDRLDRLDRLDR'))
# Out:
# 15
# 15

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from  fnmatch import *

s='3?12?14*5'

a=[]
q=[]
for i in range(0, 10**10, 1917):
    if fnmatch(str(i), s):
        q.append(i) 
        a.append(i//1917)

print(a)
print(q)
# Out:
# [183235, 1675855, 1780185, 1936575, 2040905]
# [351261495, 3212614035, 3412614645, 3712414275, 3912414885]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def f(n):
    q=[]
    for i in range(1, int(n**0.5)+1):
        if n%i==0:
            q.append(i)
            q.append(n//i)
    q=set(q)
    q=sorted(q)
    return(sum(q))

c=0
q=[]
a=[]
for i in range(500_000, 600_000000000000000):
    if str(f(i))[-1]=='6':
        c+=1
        q.append(i)
        a.append(f(i))
        if c==5:
            print(q)
            print(a)
            break
# Out:
# [500032, 500035, 500039, 500050, 500052]
# [1070356, 606816, 501456, 949716, 1333696]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=open('24.txt')
s=a.readline()
s='6966+79890--8++7887888--686---0-070008+09-9-++687999-6+80+89-670-89866-9-888+80+9+-66099-+09+--707-+0999-00797-00+87760-698-+77988+970987777667088608-6060-+7+86+70-9899687+9076+8689---7+08-6709978-6808686076700800686+7+0099-980008+-970+06--7-+69+87777606+7096607-77-669--879+006609--09+9-897789++-8+999698097-06+8870666-70700-8+9-997988+700++8-897980+7609678079+'
s=s.replace('--', '*')
s=s.replace('-+', '*')
s=s.replace('+-', '*')
s=s.replace('++', '*')
s=s.replace('*-', '*')
s=s.replace('*+', '*')
s=s.replace('6', '9')
s=s.replace('7', '9')
s=s.replace('8', '9')
s=s.replace('+', '!')
s=s.replace('-', '!')
s=s.replace('!0!', '!9!')
s=s.replace('!0', '*')
s=s.replace('!*', '*')
s=s.split('*')
print(s)
q=[]
for i in s:
    flag=0
    c=0
    for p in range(0, len(i)):
        if i[p]=='9':
            flag=1

        if flag==1:
            c+=1
    q.append(c)

print(max(q))
# Out:
# ['9999!99990', '9', '9999999', '999', '0', '90009', '9!9', '999999!9!90!99!990!99999!9!999!90!9', '99099', '09', '909', '0999', '0999', '0!99990!999', '99999!990999999999099909!9090', '9!99!90!9999999!9099!9999', '9', '9!9909999!9909999099900900999!9', '099!990009', '990', '9', '9', '99!99999909!9099909!99!999', '999', '09909', '09!9!999999', '9!999999099', '9!9990999!90900!9!9!999999!900', '9!999990!9909999099!']
# 35

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
k = 26 + 26**2 + 26**3 + 26**4 + 26**5 + 1
from itertools import *

# a=list(product(sorted('WERTYUIOPASDFGHJKLZXCVBNMQ'), repeat=6))
# c=k
# for i in a:
#     c+=1
#     # ('F', 'E', 'D', 'A', 'B', 'C')
#     s = ''
#     # s1 = ''.join(i)
#     for el in i:
#         s+=el
#     if s == 'FEDABC':
#         print(c)
#         break

print(int('543012',26)+k)
# Out:
# 73644171
