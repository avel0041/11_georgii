# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Сдал, Балл (убывание), ID (возрастание)
# Не сдал, Кол-во двоек (возрастание), ID (возрастание)
a=open('26_2.txt')
s=a.readlines()
s=s[1::]
x=9980//4

a2=[]
a1=[]
for N in s:
    w=i.split()
    wp=w[1::]
    wp=list(map(int,wp))
    
    if wp.count(2)!=0:
        a2.append([wp.count(2), int(w[0])])
    else:
        cr=sum(wp)/len(wp)
        a1.append([-cr, int(w[0])])

# [5.0, 1]
# [5.0, 2]
# [4.5, 4]
# [4.3, 3]

a1=sorted(a1)
a2=sorted(a2)

    
print(a1[x-1])
print(a2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from itertools import *

a=list(product(sorted('ТЕРМИН'), repeat=10))

#a=[2, 3, 4, 5, 6]
a=a[::-1]
a.append(1)
a=a[::-1]
a=a[3:]
a=a[::3]

c=0
for i in a:
    if (i[0]=='Е' or i[0]=='И') and i.count('Т')==1:
        c+=1

print(c)
# Out:
# 2031250

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from math import *
for N in range(10000,1,-1):
    izdelie = ceil((19 * 5 + log2(N))/8) + 40
    if izdelie * N <= 20 * 1024:
        print(N)
        break

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print((11*70*16384)/2**10)
# Out:
# 12320.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def f(a,b):
    if a==b:
        return 1
    elif a>b:
        return 0
    else:
        return f(a+1, b) +  f(a*2,b) + f(a+3,b)
    
print(f(3,12)*f(12,16))
# Out:
# 96
