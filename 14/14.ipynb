# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for x in '0123456789':
    if (int(x+'B09', 17)+ int(x+'8E8', 15))%155 ==0:
        q= (int(x+'B09', 17)+ int(x+'8E8', 15))/155
        break
print(q)
# Out:
# 194.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=[]
for x in '012345678':
    for y in '012345678':
        res = int('88'+ x + '4' + y,9) + int('7'+ x + '44' + y,11)
        if res%61==0:
            a.append(res/61)
print(min(a))
# Out:
# 2715.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=125+25**3+5**9
def fn(q):
    z=str()
    while q !=0:
        z=z+str(q%5)
        q=q//5
    z=z[::-1]
    return z

w=fn(a)
count=0
for i in w:
    if int(i) ==0:
        count=count+1
print(count)

print(w.count('0'))
# Out:
# 7
# 7

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
504
# Out:
# 504

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
w=0
for p in range(7, 36):
    for x in range(0, p):
        for y in range(0, p):
            for z in range(0, p):
                x = str(x)
                y = str(y)
                z = str(z)
                if int(y+'4'+y, p)+int(y+'65', p) - int(x+z+'33', p) ==0:
                    w=int(x+y+z, p)
print(w)
# Out:
# 117

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=2*216**6+3*36**9-432
def f(n):
    s=''
    while n>5:
        s+=str(n%6)
        n=n//6
    s=s[::-1]
    s+=str(n)
    return s

print(f(a).count('5'))
a6=f(a)
k=0

for i in a6:
    if i =='5':
        k+=1
print(k)
# Out:
# 14
# 14

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Out:
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=sorted('0123456789QWERTYUIOPASDFGHJKLZXCVBNM') [:13]
m=100000000
w=0
for x in a:
    for y in a:
        
        n1=int('8'+str(x)+'78'+str(y), 13)
        n2=int('79'+str(x)+str(y)+'7', 18)
        s=n1+n2
        if s%9==0 and s<=m:
            m=s
            w=s//9
        
print(w)
# Out:
# 113024

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=sorted(set('0123456789QWERTYUIOPASDFGHJKLZZXCVBNM'))
for p in range(5, 36):
    for x in a[:p]:
        for y in a[:p]:
            s1=int('12',p)
            s2=int('34',p)
            s3=s1*s2
            s4=int(x+y+'2',p)
            if s3==s4:
                s5=int(y+x, p)
                print(s5, p)
# Out:
# 34 6
